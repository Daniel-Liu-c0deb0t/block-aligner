# %% [markdown]
# # Block Aligner Data Analysis and Visualizations

# %% [markdown]
# This notebook contains code for collecting, cleaning, and analyzing data produced by block aligner's experiments.
#
# Run each cell one by one to reproduce the experiments. This may take a while.

# %%
import altair as alt
from altair import datum
import pandas as pd
from io import StringIO

# %%
def csv_to_pandas(csv, d = "\\s*,\\s*", t = None):
    s = StringIO("\n".join(csv))
    data = pd.read_csv(s, sep = d, thousands = t, comment = "#", engine = "python")
    return data

# %% [markdown]
# ## Block Aligner Image

# %%
# !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example block_img --release --quiet -- vis/block_img1.png vis/block_img2.png
# Out:
# path: vis/block_img1.png, img size: 1980 x 1647
# path: vis/block_img2.png, img size: 1695 x 1746

# %% [markdown]
# <img src = "block_img1.png" width = "300px" />
# <img src = "block_img2.png" width = "300px" />

# %% [markdown]
# ## Random Data Accuracy

# %%
output = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example accuracy --release --quiet
output
# Out:
# ['',
#  'len, k, insert, iter, max size, wrong, wrong % error, wrong min, wrong max',
#  '',
#  '',
#  '100, 10, false, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 10, false, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 10, true, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 10, true, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 20, false, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 20, false, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 20, true, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 20, true, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 50, false, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 50, false, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 50, true, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '100, 50, true, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 100, false, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 100, false, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 100, true, 100, 32, 100, 0.6551547438556898, 4, 1014',
#  '',
#  '',
#  '1000, 100, true, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 200, false, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 200, false, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 200, true, 100, 32, 100, 0.6778750604505338, 3, 862',
#  '',
#  '',
#  '1000, 200, true, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 500, false, 100, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 500, false, 100, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '1000, 500, true, 100, 32, 99, 1.606836248302861, 8, 452',
#  '',
#  '',
#  '1000, 500, true, 100, 2048, 1, 0.010582010582010581, 2, 2',
#  '',
#  '',
#  '10000, 1000, false, 10, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '10000, 1000, false, 10, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '10000, 1000, true, 10, 32, 10, 0.6191400141271121, 401, 9432',
#  '',
#  '',
#  '10000, 1000, true, 10, 2048, 1, 0.0004274113121527283, 3, 3',
#  '',
#  '',
#  '10000, 2000, false, 10, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '10000, 2000, false, 10, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '10000, 2000, true, 10, 32, 10, 0.9089851861059467, 834, 8415',
#  '',
#  '',
#  '10000, 2000, true, 10, 2048, 2, 0.0008353174637382569, 3, 6',
#  '',
#  '',
#  '10000, 5000, false, 10, 32, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '10000, 5000, false, 10, 2048, 0, NaN, 2147483647, -2147483648',
#  '',
#  '',
#  '10000, 5000, true, 10, 32, 10, 1.370652805452233, 73, 4700',
#  '',
#  '',
#  '10000, 5000, true, 10, 2048, 2, 0.00333479172314572, 3, 10',
#  '',
#  '',
#  '# total: 2520, wrong: 335',
#  '# Done!']

# %%
data = csv_to_pandas(output)
data
# Out:
#       len     k  insert  iter  max size  wrong  wrong % error   wrong min  \
# 0     100    10   False   100        32      0            NaN  2147483647
# 1     100    10   False   100      2048      0            NaN  2147483647
# 2     100    10    True   100        32      0            NaN  2147483647
# 3     100    10    True   100      2048      0            NaN  2147483647
# 4     100    20   False   100        32      0            NaN  2147483647
# 5     100    20   False   100      2048      0            NaN  2147483647
# 6     100    20    True   100        32      0            NaN  2147483647
# 7     100    20    True   100      2048      0            NaN  2147483647
# 8     100    50   False   100        32      0            NaN  2147483647
# 9     100    50   False   100      2048      0            NaN  2147483647
# 10    100    50    True   100        32      0            NaN  2147483647
# 11    100    50    True   100      2048      0            NaN  2147483647
# 12   1000   100   False   100        32      0            NaN  2147483647
# 13   1000   100   False   100      2048      0            NaN  2147483647
# 14   1000   100    True   100        32    100       0.655155           4
# 15   1000   100    True   100      2048      0            NaN  2147483647
# 16   1000   200   False   100        32      0            NaN  2147483647
# 17   1000   200   False   100      2048      0            NaN  2147483647
# 18   1000   200    True   100        32    100       0.677875           3
# 19   1000   200    True   100      2048      0            NaN  2147483647
# 20   1000   500   False   100        32      0            NaN  2147483647
# 21   1000   500   False   100      2048      0            NaN  2147483647
# 22   1000   500    True   100        32     99       1.606836           8
# 23   1000   500    True   100      2048      1       0.010582           2
# 24  10000  1000   False    10        32      0            NaN  2147483647
# 25  10000  1000   False    10      2048      0            NaN  2147483647
# 26  10000  1000    True    10        32     10       0.619140         401
# 27  10000  1000    True    10      2048      1       0.000427           3
# 28  10000  2000   False    10        32      0            NaN  2147483647
# 29  10000  2000   False    10      2048      0            NaN  2147483647
# 30  10000  2000    True    10        32     10       0.908985         834
# 31  10000  2000    True    10      2048      2       0.000835           3
# 32  10000  5000   False    10        32      0            NaN  2147483647
# 33  10000  5000   False    10      2048      0            NaN  2147483647
# 34  10000  5000    True    10        32     10       1.370653          73
# 35  10000  5000    True    10      2048      2       0.003335           3
#
#      wrong max
# 0  -2147483648
# 1  -2147483648
# 2  -2147483648
# 3  -2147483648
# 4  -2147483648
# 5  -2147483648
# 6  -2147483648
# 7  -2147483648
# 8  -2147483648
# 9  -2147483648
# 10 -2147483648
# 11 -2147483648
# 12 -2147483648
# 13 -2147483648
# 14        1014
# 15 -2147483648
# 16 -2147483648
# 17 -2147483648
# 18         862
# 19 -2147483648
# 20 -2147483648
# 21 -2147483648
# 22         452
# 23           2
# 24 -2147483648
# 25 -2147483648
# 26        9432
# 27           3
# 28 -2147483648
# 29 -2147483648
# 30        8415
# 31           6
# 32 -2147483648
# 33 -2147483648
# 34        4700
# 35          10

# %%
data["% wrong"] = data["wrong"] / data["iter"]
data["k %"] = data["k"] / data["len"]

# %%
alt.Chart(data, title = "Accuracy on Random DNA Sequences with 10% Insert").mark_point(opacity = 1).encode(
    x = alt.X("% wrong", axis = alt.Axis(format = "%")),
    y = alt.Y("k %:N", axis = alt.Axis(format = "~%", grid = True)),
    color = "max size:N",
    row = alt.Row("len:N", header = alt.Header(title = "length"))
).transform_filter(
    datum.insert == True
).properties(
    width = 100,
    height = 50
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Prefix Scan Benchmark

# %%
output = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo bench --quiet -- prefix_scan | grep 'bench:' | awk '{print $2"\t"$5}'
output.insert(0, "algorithm\ttime")
output
# Out:
# ['algorithm\ttime', 'bench_naive_prefix_scan\t10', 'bench_opt_prefix_scan\t1']

# %%
data = csv_to_pandas(output, d = "\t", t = ",")
data
# Out:
#                  algorithm  time
# 0  bench_naive_prefix_scan    10
# 1    bench_opt_prefix_scan     1

# %%
data["algorithm"] = data["algorithm"].map({
    "bench_naive_prefix_scan": "naive",
    "bench_opt_prefix_scan": "ours"
})
data
# Out:
#   algorithm  time
# 0     naive    10
# 1      ours     1

# %%
alt.Chart(data, title = "Prefix Scan Benchmark (AVX2)").mark_bar().encode(
    x = alt.X("time", axis = alt.Axis(title = "time (ns)")),
    y = "algorithm"
).properties(
    width = 150
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Random Data Benchmark

# %%
output = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo bench --quiet -- bench_ | grep 'bench:' | grep -v 'prefix_scan' | awk '{print $2"\t"$5}'
output
# Out:
# ['bench_parasailors_aa_1000_10000\t45,462,338',
#  'bench_parasailors_aa_100_1000\t513,484',
#  'bench_parasailors_aa_10_100\t17,177',
#  'bench_rustbio_aa_100_1000\t13,990,318',
#  'bench_rustbio_aa_10_100\t146,904',
#  'bench_scan_aa_1000_10000\t215,095',
#  'bench_scan_aa_1000_10000_insert\t1,927,528',
#  'bench_scan_aa_1000_10000_small\t210,373',
#  'bench_scan_aa_1000_10000_trace\t325,719',
#  'bench_scan_aa_100_1000\t22,329',
#  'bench_scan_aa_100_1000_insert\t42,962',
#  'bench_scan_aa_100_1000_small\t21,279',
#  'bench_scan_aa_100_1000_trace\t37,173',
#  'bench_scan_aa_10_100\t3,577',
#  'bench_scan_aa_10_100_insert\t3,709',
#  'bench_scan_aa_10_100_small\t3,189',
#  'bench_scan_aa_10_100_trace\t5,241',
#  'bench_scan_nuc_1000_10000\t201,514',
#  'bench_scan_nuc_100_1000\t21,589',
#  'bench_triple_accel_1000_10000\t7,038,138',
#  'bench_triple_accel_100_1000\t22,810']

# %%
cleaned = ["algorithm\talphabet\tk\tlength\tproperty\ttime"]
names = ["parasailors_aa", "rustbio_aa", "scan_aa", "scan_nuc", "triple_accel"]
new_names = ["parasailors\tprotein", "rust bio\tprotein", "ours\tprotein", "ours\tnucleotide", "triple accel\tnucleotide"]

for o in output:
    o = o[len("bench_"):]
    for n, nn in zip(names, new_names):
        if o.startswith(n):
            suffix = o[len(n):].replace("_", "\t")
            o = nn + suffix
            break
    if len(o.split("\t")) < len(cleaned[0].split("\t")):
        insert_idx = o.rindex("\t")
        o = o[:insert_idx] + "\tdefault" + o[insert_idx:]
    cleaned.append(o)

cleaned
# Out:
# ['algorithm\talphabet\tk\tlength\tproperty\ttime',
#  'parasailors\tprotein\t1000\t10000\tdefault\t45,462,338',
#  'parasailors\tprotein\t100\t1000\tdefault\t513,484',
#  'parasailors\tprotein\t10\t100\tdefault\t17,177',
#  'rust bio\tprotein\t100\t1000\tdefault\t13,990,318',
#  'rust bio\tprotein\t10\t100\tdefault\t146,904',
#  'ours\tprotein\t1000\t10000\tdefault\t215,095',
#  'ours\tprotein\t1000\t10000\tinsert\t1,927,528',
#  'ours\tprotein\t1000\t10000\tsmall\t210,373',
#  'ours\tprotein\t1000\t10000\ttrace\t325,719',
#  'ours\tprotein\t100\t1000\tdefault\t22,329',
#  'ours\tprotein\t100\t1000\tinsert\t42,962',
#  'ours\tprotein\t100\t1000\tsmall\t21,279',
#  'ours\tprotein\t100\t1000\ttrace\t37,173',
#  'ours\tprotein\t10\t100\tdefault\t3,577',
#  'ours\tprotein\t10\t100\tinsert\t3,709',
#  'ours\tprotein\t10\t100\tsmall\t3,189',
#  'ours\tprotein\t10\t100\ttrace\t5,241',
#  'ours\tnucleotide\t1000\t10000\tdefault\t201,514',
#  'ours\tnucleotide\t100\t1000\tdefault\t21,589',
#  'triple accel\tnucleotide\t1000\t10000\tdefault\t7,038,138',
#  'triple accel\tnucleotide\t100\t1000\tdefault\t22,810']

# %%
data = csv_to_pandas(cleaned, d = "\t", t = ",")
data
# Out:
#        algorithm    alphabet     k  length property      time
# 0    parasailors     protein  1000   10000  default  45462338
# 1    parasailors     protein   100    1000  default    513484
# 2    parasailors     protein    10     100  default     17177
# 3       rust bio     protein   100    1000  default  13990318
# 4       rust bio     protein    10     100  default    146904
# 5           ours     protein  1000   10000  default    215095
# 6           ours     protein  1000   10000   insert   1927528
# 7           ours     protein  1000   10000    small    210373
# 8           ours     protein  1000   10000    trace    325719
# 9           ours     protein   100    1000  default     22329
# 10          ours     protein   100    1000   insert     42962
# 11          ours     protein   100    1000    small     21279
# 12          ours     protein   100    1000    trace     37173
# 13          ours     protein    10     100  default      3577
# 14          ours     protein    10     100   insert      3709
# 15          ours     protein    10     100    small      3189
# 16          ours     protein    10     100    trace      5241
# 17          ours  nucleotide  1000   10000  default    201514
# 18          ours  nucleotide   100    1000  default     21589
# 19  triple accel  nucleotide  1000   10000  default   7038138
# 20  triple accel  nucleotide   100    1000  default     22810

# %%
data["algorithm property"] = data["algorithm"] + " " + data["property"]
data["time"] /= 1000

# %%
alt.Chart(data, title = "Random Protein Sequences Benchmark (AVX2)").mark_point(opacity = 1).encode(
    x = alt.X("time", axis = alt.Axis(title = "time (us)"), scale = alt.Scale(type = "log")),
    y = alt.Y("algorithm property", axis = alt.Axis(title = "algorithm", grid = True), sort = alt.EncodingSortField(field = "time")),
    color = "length:N"
).transform_filter(
    datum.alphabet == "protein"
).properties(
    width = 200,
    height = 150
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data, title = "Random DNA Sequences Benchmark (AVX2)").mark_point(opacity = 1).encode(
    x = alt.X("time", axis = alt.Axis(title = "time (us)"), scale = alt.Scale(type = "log")),
    y = alt.Y("algorithm property", axis = alt.Axis(title = "algorithm", grid = True), sort = alt.EncodingSortField(field = "time")),
    color = "length:N"
).transform_filter(
    datum.alphabet == "nucleotide"
).properties(
    width = 200,
    height = 50
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Uniclust 30 Data Accuracy

# %%
output = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example uc_accuracy --release --quiet
output
# Out:
# ['# seq identity is lower bound (inclusive)',
#  'dataset, max size, seq identity, count, wrong, wrong % error',
#  'uc30_0.95, 32, 0, 0, 0, NaN',
#  'uc30_0.95, 32, 0.1, 0, 0, NaN',
#  'uc30_0.95, 32, 0.2, 14, 0, NaN',
#  'uc30_0.95, 32, 0.3, 873, 48, 0.23644643580689115',
#  'uc30_0.95, 32, 0.4, 1166, 72, 0.2588941794696058',
#  'uc30_0.95, 32, 0.5, 951, 38, 0.26989686669054164',
#  'uc30_0.95, 32, 0.6, 923, 29, 0.26600576925717145',
#  'uc30_0.95, 32, 0.7, 789, 21, 0.2507672376509289',
#  'uc30_0.95, 32, 0.8, 747, 10, 0.21092575017184195',
#  'uc30_0.95, 32, 0.9, 1537, 20, 0.13902065073668682',
#  '',
#  '# total: 7000, wrong: 238, wrong % error: 0.24418420416118747, length avg: 329.554, length min: 22, length max: 8881',
#  '',
#  'uc30_0.95, 256, 0, 0, 0, NaN',
#  'uc30_0.95, 256, 0.1, 0, 0, NaN',
#  'uc30_0.95, 256, 0.2, 14, 0, NaN',
#  'uc30_0.95, 256, 0.3, 873, 6, 0.022628943599678163',
#  'uc30_0.95, 256, 0.4, 1166, 8, 0.07534822871256201',
#  'uc30_0.95, 256, 0.5, 951, 4, 0.0327230834375036',
#  'uc30_0.95, 256, 0.6, 923, 4, 0.06402485654988788',
#  'uc30_0.95, 256, 0.7, 789, 5, 0.02126386751404335',
#  'uc30_0.95, 256, 0.8, 747, 1, 0.0006338028169014084',
#  'uc30_0.95, 256, 0.9, 1537, 6, 0.041255693000085136',
#  '',
#  '# total: 7000, wrong: 34, wrong % error: 0.04353054557752235, length avg: 329.554, length min: 22, length max: 8881',
#  '',
#  'uc30, 32, 0, 0, 0, NaN',
#  'uc30, 32, 0.1, 0, 0, NaN',
#  'uc30, 32, 0.2, 192, 82, 0.9296095255349193',
#  'uc30, 32, 0.3, 1170, 292, 0.5783549949752733',
#  'uc30, 32, 0.4, 1182, 277, 0.5775144510164206',
#  'uc30, 32, 0.5, 1160, 231, 0.550504170149309',
#  'uc30, 32, 0.6, 1044, 198, 0.5351011309414313',
#  'uc30, 32, 0.7, 847, 106, 0.5582347337083104',
#  'uc30, 32, 0.8, 694, 89, 0.4931958429409617',
#  'uc30, 32, 0.9, 711, 19, 0.3312230239174083',
#  '',
#  '# total: 7000, wrong: 1294, wrong % error: 0.5777095664902185, length avg: 302.51342857142856, length min: 25, length max: 8293',
#  '',
#  'uc30, 256, 0, 0, 0, NaN',
#  'uc30, 256, 0.1, 0, 0, NaN',
#  'uc30, 256, 0.2, 192, 10, 0.28500462007055505',
#  'uc30, 256, 0.3, 1170, 34, 0.16086381139637815',
#  'uc30, 256, 0.4, 1182, 33, 0.14485337870775553',
#  'uc30, 256, 0.5, 1160, 33, 0.1602361717460911',
#  'uc30, 256, 0.6, 1044, 31, 0.1158979412376571',
#  'uc30, 256, 0.7, 847, 13, 0.08761607776391131',
#  'uc30, 256, 0.8, 694, 20, 0.07686074477851476',
#  'uc30, 256, 0.9, 711, 8, 0.04555490438794617',
#  '',
#  '# total: 7000, wrong: 182, wrong % error: 0.13747730919302983, length avg: 302.51342857142856, length min: 25, length max: 8293',
#  '',
#  '# Done!']

# %%
data = csv_to_pandas(output)
data
# Out:
#       dataset  max size  seq identity  count  wrong  wrong % error
# 0   uc30_0.95        32           0.0      0      0            NaN
# 1   uc30_0.95        32           0.1      0      0            NaN
# 2   uc30_0.95        32           0.2     14      0            NaN
# 3   uc30_0.95        32           0.3    873     48       0.236446
# 4   uc30_0.95        32           0.4   1166     72       0.258894
# 5   uc30_0.95        32           0.5    951     38       0.269897
# 6   uc30_0.95        32           0.6    923     29       0.266006
# 7   uc30_0.95        32           0.7    789     21       0.250767
# 8   uc30_0.95        32           0.8    747     10       0.210926
# 9   uc30_0.95        32           0.9   1537     20       0.139021
# 10  uc30_0.95       256           0.0      0      0            NaN
# 11  uc30_0.95       256           0.1      0      0            NaN
# 12  uc30_0.95       256           0.2     14      0            NaN
# 13  uc30_0.95       256           0.3    873      6       0.022629
# 14  uc30_0.95       256           0.4   1166      8       0.075348
# 15  uc30_0.95       256           0.5    951      4       0.032723
# 16  uc30_0.95       256           0.6    923      4       0.064025
# 17  uc30_0.95       256           0.7    789      5       0.021264
# 18  uc30_0.95       256           0.8    747      1       0.000634
# 19  uc30_0.95       256           0.9   1537      6       0.041256
# 20       uc30        32           0.0      0      0            NaN
# 21       uc30        32           0.1      0      0            NaN
# 22       uc30        32           0.2    192     82       0.929610
# 23       uc30        32           0.3   1170    292       0.578355
# 24       uc30        32           0.4   1182    277       0.577514
# 25       uc30        32           0.5   1160    231       0.550504
# 26       uc30        32           0.6   1044    198       0.535101
# 27       uc30        32           0.7    847    106       0.558235
# 28       uc30        32           0.8    694     89       0.493196
# 29       uc30        32           0.9    711     19       0.331223
# 30       uc30       256           0.0      0      0            NaN
# 31       uc30       256           0.1      0      0            NaN
# 32       uc30       256           0.2    192     10       0.285005
# 33       uc30       256           0.3   1170     34       0.160864
# 34       uc30       256           0.4   1182     33       0.144853
# 35       uc30       256           0.5   1160     33       0.160236
# 36       uc30       256           0.6   1044     31       0.115898
# 37       uc30       256           0.7    847     13       0.087616
# 38       uc30       256           0.8    694     20       0.076861
# 39       uc30       256           0.9    711      8       0.045555

# %%
data["% wrong"] = data["wrong"] / data["count"]
data["seq identity"] = data["seq identity"].map({
    0.0: "0-10%",
    0.1: "10-20%",
    0.2: "20-30%",
    0.3: "30-40%",
    0.4: "40-50%",
    0.5: "50-60%",
    0.6: "60-70%",
    0.7: "70-80%",
    0.8: "80-90%",
    0.9: "90-100%"
})
data
# Out:
#       dataset  max size seq identity  count  wrong  wrong % error   % wrong
# 0   uc30_0.95        32        0-10%      0      0            NaN       NaN
# 1   uc30_0.95        32       10-20%      0      0            NaN       NaN
# 2   uc30_0.95        32       20-30%     14      0            NaN  0.000000
# 3   uc30_0.95        32       30-40%    873     48       0.236446  0.054983
# 4   uc30_0.95        32       40-50%   1166     72       0.258894  0.061750
# 5   uc30_0.95        32       50-60%    951     38       0.269897  0.039958
# 6   uc30_0.95        32       60-70%    923     29       0.266006  0.031419
# 7   uc30_0.95        32       70-80%    789     21       0.250767  0.026616
# 8   uc30_0.95        32       80-90%    747     10       0.210926  0.013387
# 9   uc30_0.95        32      90-100%   1537     20       0.139021  0.013012
# 10  uc30_0.95       256        0-10%      0      0            NaN       NaN
# 11  uc30_0.95       256       10-20%      0      0            NaN       NaN
# 12  uc30_0.95       256       20-30%     14      0            NaN  0.000000
# 13  uc30_0.95       256       30-40%    873      6       0.022629  0.006873
# 14  uc30_0.95       256       40-50%   1166      8       0.075348  0.006861
# 15  uc30_0.95       256       50-60%    951      4       0.032723  0.004206
# 16  uc30_0.95       256       60-70%    923      4       0.064025  0.004334
# 17  uc30_0.95       256       70-80%    789      5       0.021264  0.006337
# 18  uc30_0.95       256       80-90%    747      1       0.000634  0.001339
# 19  uc30_0.95       256      90-100%   1537      6       0.041256  0.003904
# 20       uc30        32        0-10%      0      0            NaN       NaN
# 21       uc30        32       10-20%      0      0            NaN       NaN
# 22       uc30        32       20-30%    192     82       0.929610  0.427083
# 23       uc30        32       30-40%   1170    292       0.578355  0.249573
# 24       uc30        32       40-50%   1182    277       0.577514  0.234349
# 25       uc30        32       50-60%   1160    231       0.550504  0.199138
# 26       uc30        32       60-70%   1044    198       0.535101  0.189655
# 27       uc30        32       70-80%    847    106       0.558235  0.125148
# 28       uc30        32       80-90%    694     89       0.493196  0.128242
# 29       uc30        32      90-100%    711     19       0.331223  0.026723
# 30       uc30       256        0-10%      0      0            NaN       NaN
# 31       uc30       256       10-20%      0      0            NaN       NaN
# 32       uc30       256       20-30%    192     10       0.285005  0.052083
# 33       uc30       256       30-40%   1170     34       0.160864  0.029060
# 34       uc30       256       40-50%   1182     33       0.144853  0.027919
# 35       uc30       256       50-60%   1160     33       0.160236  0.028448
# 36       uc30       256       60-70%   1044     31       0.115898  0.029693
# 37       uc30       256       70-80%    847     13       0.087616  0.015348
# 38       uc30       256       80-90%    694     20       0.076861  0.028818
# 39       uc30       256      90-100%    711      8       0.045555  0.011252

# %%
alt.Chart(data, title = "Uniclust 30 Accuracy").mark_bar().encode(
    x = "seq identity",
    y = alt.Y("% wrong", axis = alt.Axis(format = "%")),
    column = "max size:N",
    row = "dataset:N"
).properties(
    width = 150,
    height = 150
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data, title = "Uniclust 30 Wrong % Error").mark_bar().encode(
    x = "seq identity",
    y = alt.Y("wrong % error", axis = alt.Axis(format = "%")),
    column = "max size:N",
    row = "dataset"
).properties(
    width = 150,
    height = 150
)
# Out:
# alt.Chart(...)

# %%
agg_data = data.copy()
agg_data = agg_data.groupby(["dataset", "max size"]).agg({"count": "sum", "wrong": "sum"}).reset_index()
agg_data["% wrong"] = agg_data["wrong"] / agg_data["count"]
agg_data
# Out:
#      dataset  max size  count  wrong   % wrong
# 0       uc30        32   7000   1294  0.184857
# 1       uc30       256   7000    182  0.026000
# 2  uc30_0.95        32   7000    238  0.034000
# 3  uc30_0.95       256   7000     34  0.004857

# %%
alt.Chart(agg_data, title = "Overall Uniclust 30 Accuracy").mark_bar().encode(
    x = alt.X("max size:N", axis = None),
    y = alt.Y("% wrong", axis = alt.Axis(format = "%")),
    column = alt.Column("dataset", header = alt.Header(orient = "bottom")),
    color = alt.Color("max size:N")
).properties(
    width = 50,
    height = 100
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Uniclust 30 Data Benchmark

# %%
output = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example uc_bench --release --quiet
output
# Out:
# ['# time (s)',
#  'algorithm, dataset, time',
#  'ours, uc30, 0.096531815',
#  'ours, uc30 0.95, 0.082853501',
#  'parasail, uc30, 0.751147802',
#  'parasail, uc30 0.95, 0.871423509']

# %%
data = csv_to_pandas(output)
data
# Out:
#   algorithm    dataset      time
# 0      ours       uc30  0.096532
# 1      ours  uc30 0.95  0.082854
# 2  parasail       uc30  0.751148
# 3  parasail  uc30 0.95  0.871424

# %%
alt.Chart(data, title = "Overall Uniclust 30 Benchmark (AVX2)").mark_bar().encode(
    x = alt.X("algorithm", axis = None),
    y = alt.Y("time", axis = alt.Axis(title = "time (s)")),
    column = alt.Column("dataset", header = alt.Header(orient = "bottom")),
    color = "algorithm"
).properties(
    width = 50,
    height = 100
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Nanopore Data Compare and Benchmark Setup
#
# To run the comparisons and benchmarks below, you need to clone the following repos, place them in the same directory where this repo (block aligner) is located, and follow their setup instructions:
# * [diff-bench-paper](https://github.com/Daniel-Liu-c0deb0t/diff-bench-paper)
# * [adaptivebandbench](https://github.com/Daniel-Liu-c0deb0t/adaptivebandbench)

# %% [markdown]
# ## Nanopore Data Compare

# %%
output = !cd ../../diff-bench-paper/supplementary_data/benchmark_codes && ./custom_scores.sh 2>&1 | grep '\.tsv'
output
# Out:
# ['scores_l1000.tsv',
#  'scores_l10000.tsv',
#  'scores_l25000.tsv',
#  'scores_default.tsv']

# %%
lengths = []
for f in output:
    l = f[len("scores_"):f.index(".")]
    lengths.append(l[1:] if l[0] == "l" else l)
lengths
# Out:
# ['1000', '10000', '25000', 'default']

# %%
path_prefix = "../diff-bench-paper/"
outputs = []
for f in output:
    o = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example compare --release --quiet -- {path_prefix + f}
    outputs.append(o)
outputs
# Out:
# [['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 16, 0.1168083944994962, 1649, 0.014457400441640959',
#   '',
#   '64, 1734, 2, 0.0035435779816513765, 1674, 0.01808772210169801',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 112, 0.11158480489223006, 1558, 0.00231192171488459',
#   '',
#   '64, 1734, 10, 0.02004804219719002, 1681, 0.01227283972235607',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 196, 0.12252339253065558, 906, 0.0033348114113708398',
#   '',
#   '64, 1734, 6, 0.06846053563562754, 1113, 0.028906498881623614',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 220, 0.11254060955901618, 50, 0.050686760651400126',
#   '',
#   '64, 1734, 10, 0.04866354196777517, 241, 0.13470260660734062',
#   '# Done!']]

# %%
data = []
for o in outputs:
    d = csv_to_pandas(o)
    data.append(d)
data = pd.concat(data, keys = lengths)
data = data.reset_index()
data = data.drop(columns = ["level_1"])
data = data.rename(columns = {"level_0": "length"})
data["band width"] = 32
data
# Out:
#     length  max size  total  other better  other % better  us better  \
# 0     1000        32   1734            16        0.116808       1649
# 1     1000        64   1734             2        0.003544       1674
# 2    10000        32   1734           112        0.111585       1558
# 3    10000        64   1734            10        0.020048       1681
# 4    25000        32   1734           196        0.122523        906
# 5    25000        64   1734             6        0.068461       1113
# 6  default        32   1734           220        0.112541         50
# 7  default        64   1734            10        0.048664        241
#
#    us % better  band width
# 0     0.014457          32
# 1     0.018088          32
# 2     0.002312          32
# 3     0.012273          32
# 4     0.003335          32
# 5     0.028906          32
# 6     0.050687          32
# 7     0.134703          32

# %%
output = !cd ../../adaptivebandbench && ./custom_scores.sh 2>&1 | grep '\.tsv'
output
# Out:
# ['scores_l1000_b256.tsv',
#  'scores_l10000_b256.tsv',
#  'scores_l10000_b2048.tsv',
#  'scores_b256.tsv',
#  'scores_b2048.tsv']

# %%
lengths = []
band_widths = []
for f in output:
    l = f[len("scores_"):f.index(".")]
    if l[0] == "l":
        lengths.append(l[1:l.index("_")])
        l = l[l.index("_") + 1:]
    else:
        lengths.append("default")
    if l[0] == "b":
        band_widths.append(l[1:])
print(lengths)
print(band_widths)
# Out:
# ['1000', '10000', '10000', 'default', 'default']
# ['256', '256', '2048', '256', '2048']

# %%
path_prefix = "../adaptivebandbench/"
outputs = []
for f in output:
    o = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example compare --release --quiet -- {path_prefix + f}
    outputs.append(o)
outputs
# Out:
# [['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 46, 0.16641503565322546, 0, NaN',
#   '',
#   '64, 1734, 4, 0.032013001111673656, 0, NaN',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 135, 0.15257955216457833, 1589, 0.618058455288836',
#   '',
#   '64, 1734, 104, 0.046379245670845254, 1614, 0.619612581289139',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 202, 0.17373604648395774, 0, NaN',
#   '',
#   '64, 1734, 117, 0.05988456581435015, 0, NaN',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 137, 0.1687138353530413, 1593, 0.8412070978900152',
#   '',
#   '64, 1734, 110, 0.06935021417881979, 1622, 0.8435908523540999',
#   '# Done!'],
#  ['max size, total, other better, other % better, us better, us % better',
#   '',
#   '32, 1734, 269, 0.21942860528456848, 382, 0.1471431574003461',
#   '',
#   '64, 1734, 136, 0.08901162984077253, 420, 0.15565046754838147',
#   '# Done!']]

# %%
data2 = []
for o in outputs:
    d = csv_to_pandas(o)
    data2.append(d)
index = list(zip(lengths, band_widths))
data2 = pd.concat(data2, keys = index)
data2 = data2.reset_index()
data2 = data2.drop(columns = ["level_2"])
data2 = data2.rename(columns = {"level_0": "length", "level_1": "band width"})
data2
# Out:
#     length band width  max size  total  other better  other % better  \
# 0     1000        256        32   1734            46        0.166415
# 1     1000        256        64   1734             4        0.032013
# 2    10000        256        32   1734           135        0.152580
# 3    10000        256        64   1734           104        0.046379
# 4    10000       2048        32   1734           202        0.173736
# 5    10000       2048        64   1734           117        0.059885
# 6  default        256        32   1734           137        0.168714
# 7  default        256        64   1734           110        0.069350
# 8  default       2048        32   1734           269        0.219429
# 9  default       2048        64   1734           136        0.089012
#
#    us better  us % better
# 0          0          NaN
# 1          0          NaN
# 2       1589     0.618058
# 3       1614     0.619613
# 4          0          NaN
# 5          0          NaN
# 6       1593     0.841207
# 7       1622     0.843591
# 8        382     0.147143
# 9        420     0.155650

# %%
data["other better %"] = data["other better"] / data["total"]
data["us better %"] = data["us better"] / data["total"]

data2["other better %"] = data2["other better"] / data2["total"]
data2["us better %"] = data2["us better"] / data2["total"]

# %%
cleaned = data.copy()
cleaned = cleaned.melt(id_vars = ["length", "band width", "max size"], value_vars = ["us better %", "other better %"])
cleaned["variable"] = cleaned["variable"].map({"us better %": "ours", "other better %": "adaptive banding"})

cleaned2 = data2.copy()
cleaned2 = cleaned2.melt(id_vars = ["length", "band width", "max size"], value_vars = ["us better %", "other better %"])
cleaned2["variable"] = cleaned2["variable"].map({"us better %": "ours", "other better %": "static banding"})

# %%
alt.Chart(cleaned, title = "Comparison with Adaptive Banding").mark_line(point = True).encode(
    x = "length",
    y = alt.Y("value", axis = alt.Axis(title = "better %")),
    color = alt.Color("variable", title = "algorithm")
).transform_filter(
    datum["max size"] == 32
).properties(
    width = 150,
    height = 100
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cleaned2, title = "Comparison with Static Banding").mark_line(point = True).encode(
    x = "length",
    y = alt.Y("value", axis = alt.Axis(title = "better %")),
    color = alt.Color("variable", title = "algorithm"),
    row = "max size",
    column = "band width"
).properties(
    width = 100,
    height = 75
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Nanopore Data Benchmark

# %%
output = !cd .. && RUSTFLAGS="-C target-cpu=native" cargo run --example nanopore_bench --release --quiet
output
# Out:
# ['# time (s)',
#  'algorithm, dataset, time',
#  'ours, nanopore, 1.110912643',
#  'ours, random, 2.721127846']

# %%
data = csv_to_pandas(output)
data
# Out:
#   algorithm   dataset      time
# 0      ours  nanopore  1.110913
# 1      ours    random  2.721128

# %%
output2 = !cd ../../diff-bench-paper/supplementary_data/benchmark_codes && ./custom_bench.sh

for i, o in enumerate(output2):
    if o.startswith("cells("):
        break
output2 = output2[i + 1:]

output2.insert(0, "algorithm\tfill time\ttrace time\tconvert time\ttotal time\tscore\tfail")
output2
# Out:
# ['algorithm\tfill time\ttrace time\tconvert time\ttotal time\tscore\tfail',
#  'editdist\t467711000\t167381000\t65943000\t701035000\t6880489\t0',
#  'non-diff\t723317000\t264738000\t60186000\t1048241000\t27124786\t52',
#  'diff-raw\t616204000\t207789000\t62363000\t886356000\t27291141\t32',
#  'libgaba\t440100000\t153316000\t31539000\t624955000\t27121546\t53',
#  'edlib\t28457406000\t19580966000\t107922000\t48146294000\t37\t0',
#  'seqan\t90204237000\t0\t0\t90204237000\t0\t0']

# %%
data2 = csv_to_pandas(output2, d = "\t")
data2
# Out:
#   algorithm    fill time   trace time  convert time   total time     score  \
# 0  editdist    467711000    167381000      65943000    701035000   6880489
# 1  non-diff    723317000    264738000      60186000   1048241000  27124786
# 2  diff-raw    616204000    207789000      62363000    886356000  27291141
# 3   libgaba    440100000    153316000      31539000    624955000  27121546
# 4     edlib  28457406000  19580966000     107922000  48146294000        37
# 5     seqan  90204237000            0             0  90204237000         0
#
#    fail
# 0     0
# 1    52
# 2    32
# 3    53
# 4     0
# 5     0

# %%
cleaned2 = data2.drop(columns = ["trace time", "convert time", "total time", "score", "fail"])
cleaned2 = cleaned2.rename(columns = {"fill time": "time"})
cleaned2["time"] /= 1e9
cleaned2
# Out:
#   algorithm       time
# 0  editdist   0.467711
# 1  non-diff   0.723317
# 2  diff-raw   0.616204
# 3   libgaba   0.440100
# 4     edlib  28.457406
# 5     seqan  90.204237

# %%
cleaned = data.drop(index = [1])
cleaned = cleaned.drop(columns = ["dataset"])
cleaned = cleaned.append(cleaned2, ignore_index = True)
cleaned
# Out:
#   algorithm       time
# 0      ours   1.110913
# 1  editdist   0.467711
# 2  non-diff   0.723317
# 3  diff-raw   0.616204
# 4   libgaba   0.440100
# 5     edlib  28.457406
# 6     seqan  90.204237

# %%
chart1 = alt.Chart(cleaned, title = "Nanopore Data Benchmark (AVX2)").mark_point(opacity = 1).encode(
    x = alt.X("time", axis = alt.Axis(title = "time (s)", grid = True), scale = alt.Scale(type = "log")),
    y = alt.Y("algorithm", axis = alt.Axis(grid = True), sort = alt.EncodingSortField(field = "time"))
).transform_filter(datum.algorithm != "ours")

chart2 = alt.Chart(cleaned).mark_point(color = "red").encode(
    x = alt.X("time", axis = alt.Axis(title = "time (s)", grid = True), scale = alt.Scale(type = "log")),
    y = alt.Y("algorithm", axis = alt.Axis(grid = True), sort = alt.EncodingSortField(field = "time"))
).transform_filter(datum.algorithm == "ours")

(chart1 + chart2).properties(
    width = 150,
    height = 150
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## WASM SIMD
#
# [Wasmtime](https://wasmtime.dev/) is needed to run the webassembly code.

# %%
output = !CARGO_TARGET_WASM32_WASI_RUNNER="wasmtime --wasm-features simd --" RUSTFLAGS="-C target-feature=+simd128" cargo bench --target=wasm32-wasi --quiet -- --nocapture | grep 'bench:' | awk '{print $2"\t"$5}'
output
# Out:
# ['bench_rustbio_aa_100_1000\t25,000,661',
#  'bench_rustbio_aa_10_100\t252,371',
#  'bench_scan_aa_1000_10000\t1,913,442',
#  'bench_scan_aa_1000_10000_insert\t22,229,868',
#  'bench_scan_aa_1000_10000_small\t678,044',
#  'bench_scan_aa_1000_10000_trace\t2,142,564',
#  'bench_scan_aa_100_1000\t113,246',
#  'bench_scan_aa_100_1000_insert\t258,796',
#  'bench_scan_aa_100_1000_small\t66,275',
#  'bench_scan_aa_100_1000_trace\t134,518',
#  'bench_scan_aa_10_100\t8,201',
#  'bench_scan_aa_10_100_insert\t8,699',
#  'bench_scan_aa_10_100_small\t5,859',
#  'bench_scan_aa_10_100_trace\t10,192',
#  'bench_scan_nuc_1000_10000\t623,530',
#  'bench_scan_nuc_100_1000\t63,789']

# %%
cleaned = ["algorithm\talphabet\tk\tlength\tproperty\ttime"]
names = ["rustbio_aa", "scan_aa", "scan_nuc"]
new_names = ["rust bio\tprotein", "ours\tprotein", "ours\tnucleotide"]

for o in output:
    o = o[len("bench_"):]
    for n, nn in zip(names, new_names):
        if o.startswith(n):
            suffix = o[len(n):].replace("_", "\t")
            o = nn + suffix
            break
    if len(o.split("\t")) < len(cleaned[0].split("\t")):
        insert_idx = o.rindex("\t")
        o = o[:insert_idx] + "\tdefault" + o[insert_idx:]
    cleaned.append(o)

cleaned
# Out:
# ['algorithm\talphabet\tk\tlength\tproperty\ttime',
#  'rust bio\tprotein\t100\t1000\tdefault\t25,000,661',
#  'rust bio\tprotein\t10\t100\tdefault\t252,371',
#  'ours\tprotein\t1000\t10000\tdefault\t1,913,442',
#  'ours\tprotein\t1000\t10000\tinsert\t22,229,868',
#  'ours\tprotein\t1000\t10000\tsmall\t678,044',
#  'ours\tprotein\t1000\t10000\ttrace\t2,142,564',
#  'ours\tprotein\t100\t1000\tdefault\t113,246',
#  'ours\tprotein\t100\t1000\tinsert\t258,796',
#  'ours\tprotein\t100\t1000\tsmall\t66,275',
#  'ours\tprotein\t100\t1000\ttrace\t134,518',
#  'ours\tprotein\t10\t100\tdefault\t8,201',
#  'ours\tprotein\t10\t100\tinsert\t8,699',
#  'ours\tprotein\t10\t100\tsmall\t5,859',
#  'ours\tprotein\t10\t100\ttrace\t10,192',
#  'ours\tnucleotide\t1000\t10000\tdefault\t623,530',
#  'ours\tnucleotide\t100\t1000\tdefault\t63,789']

# %%
data = csv_to_pandas(cleaned, d = "\t", t = ",")
data
# Out:
#    algorithm    alphabet     k  length property      time
# 0   rust bio     protein   100    1000  default  25000661
# 1   rust bio     protein    10     100  default    252371
# 2       ours     protein  1000   10000  default   1913442
# 3       ours     protein  1000   10000   insert  22229868
# 4       ours     protein  1000   10000    small    678044
# 5       ours     protein  1000   10000    trace   2142564
# 6       ours     protein   100    1000  default    113246
# 7       ours     protein   100    1000   insert    258796
# 8       ours     protein   100    1000    small     66275
# 9       ours     protein   100    1000    trace    134518
# 10      ours     protein    10     100  default      8201
# 11      ours     protein    10     100   insert      8699
# 12      ours     protein    10     100    small      5859
# 13      ours     protein    10     100    trace     10192
# 14      ours  nucleotide  1000   10000  default    623530
# 15      ours  nucleotide   100    1000  default     63789

# %%
data["algorithm property"] = data["algorithm"] + " " + data["property"]
data["time"] /= 1000

# %%
alt.Chart(data, title = "Random Protein Sequences Benchmark (WASM SIMD)").mark_point(opacity = 1).encode(
    x = alt.X("time", axis = alt.Axis(title = "time (us)"), scale = alt.Scale(type = "log")),
    y = alt.Y("algorithm property", axis = alt.Axis(title = "algorithm", grid = True), sort = alt.EncodingSortField(field = "time")),
    color = "length:N"
).transform_filter(
    datum.alphabet == "protein"
).properties(
    width = 200,
    height = 150
)
# Out:
# alt.Chart(...)
